# %%
import pickle
import json

file_path = "F:\KWS\TEST_DUMMY_FINAL\TEST_DUMMY_FINAL\GT_dummy_final.pkl"

with open(file_path, "rb") as file:
    data = pickle.load(file)

# Pretty-print the dictionary as JSON
print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "./DATA/TEST_DUMMY_FINAL/0.wav": [
#       {
#         "keyword": "رقیق",
#         "start_time": 1.6009375,
#         "end_time": 2.6009374999999997
#       },
#       {
#         "keyword": "خوششون",
#         "start_time": 5.1909374999999995,
#         "end_time": 6.1909374999999995
#       }
#     ]
#   },
#   {
#     "./DATA/TEST_DUMMY_FINAL/1.wav": [
#       {
#         "keyword": "އޮފިސަރ",
#         "start_time": 2.65,
#         "end_time": 3.65
#       }
#     ]
#   },
#   {
#     "./DATA/TEST_DUMMY_FINAL/2.wav": [
#       {
#         "keyword": "принципиальной",
#         "start_time": 2.63,
#         "end_time": 3.63
#       },
#       {
#         "keyword": "droit",
#         "start_time": 10.0063125,
#         "end_time": 11.0063125
#       },
#       {
#         "keyword": "خواهم",
#         "start_time": 13.734874999999999,
#         "end_time": 14.734874999999999
#       },
#       {
#         "keyword": "droit",
#         "start_time": 17.304875,
# ...

# %%
import pickle
import json

file_path = r"F:\KWS\TEST_DUMMY_FINAL\TEST_DUMMY_FINAL\kw_to_id.pkl"
with open(file_path, "rb") as file:
    data = pickle.load(file)

# Print data in a nicely formatted JSON style
print(json.dumps(data, indent=4, ensure_ascii=False))
# Out:
# {
#     "أذهب": 0,
#     "أسبانيا": 1,
#     "أشاهد": 2,
#     "أطول": 3,
#     "أعطتني": 4,
#     "أغلق": 5,
#     "أولاد": 6,
#     "إياها": 7,
#     "الأسئلة": 8,
#     "التي": 9,
#     "الزواج": 10,
#     "السابعة": 11,
#     "السيارات": 12,
#     "الشيطان": 13,
#     "الغيوم": 14,
#     "القدم": 15,
#     "الكل": 16,
#     "المعركة": 17,
#     "المكتب": 18,
#     "انتظر": 19,
#     "بدأ": 20,
#     "بعض": 21,
#     "تستشير": 22,
#     "تعبت": 23,
#     "تقع": 24,
#     "جدا": 25,
#     "جيد": 26,
#     "دعني": 27,
#     "ربما": 28,
#     "رفض": 29,
#     "سمعت": 30,
#     "سيارة": 31,
#     "صورة": 32,
#     "طوال": 33,
#     "عمري": 34,
#     "عمي": 35,
#     "فادحة": 36,
#     "فعله": 37,
#     "قبل": 38,
#     "كتاب": 39,
#     "كتابك": 40,
#     "كذلك": 41,
#     "كلها": 42,
#     "لإصلاح": 43,
#     "للحظة": 44,
#     "ملك": 45,
#     "وحده": 46,
#     "ياباني": 47,
#     "يسمح": 48,
#     "يكفي": 49,
#     "অলপ": 50,
#     "আমাৰ": 51,
#     "এখন": 52,
#     "এজন": 53,
# ...
